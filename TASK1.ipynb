# %%
# !pip install numpy
# !pip install scipy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file1=pd.read_csv('task2a.csv',header=0)

# %%
file2=pd.read_csv('task2b.csv')

# %%
file1.head()
# Out:
#           timestamp  new_bike_shares
# 0  04/01/2015 00:00              182
# 1  04/01/2015 01:00              138
# 2  04/01/2015 02:00              134
# 3  04/01/2015 03:00               72
# 4  04/01/2015 04:00               47

# %%
file1.shape
# Out:
# (17414, 2)

# %%
file2.head()
# Out:
#           timestamp  temperature  feels_like_temp  humidity  wind_speed  \
# 0  04/01/2015 00:00          3.0              2.0      93.0         6.0
# 1  04/01/2015 01:00          3.0              2.5      93.0         5.0
# 2  04/01/2015 02:00          2.5              2.5      96.5         0.0
# 3  04/01/2015 03:00          2.0              2.0     100.0         0.0
# 4  04/01/2015 04:00          2.0              0.0      93.0         6.5
#
#    is_weekend  season_code
# 0           1            3
# 1           1            3
# 2           1            3
# 3           1            3
# 4           1            3

# %%
file2.shape
# Out:
# (17414, 7)

# %%
file2.drop('season_code', inplace=True, axis=1)

# %%
file2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   timestamp        17414 non-null  object
#  1   temperature      17414 non-null  float64
#  2   feels_like_temp  17414 non-null  float64
#  3   humidity         17414 non-null  float64
#  4   wind_speed       17414 non-null  float64
#  5   is_weekend       17414 non-null  int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 816.4+ KB

# %%
file2.head()
# Out:
#           timestamp  temperature  feels_like_temp  humidity  wind_speed  \
# 0  04/01/2015 00:00          3.0              2.0      93.0         6.0
# 1  04/01/2015 01:00          3.0              2.5      93.0         5.0
# 2  04/01/2015 02:00          2.5              2.5      96.5         0.0
# 3  04/01/2015 03:00          2.0              2.0     100.0         0.0
# 4  04/01/2015 04:00          2.0              0.0      93.0         6.5
#
#    is_weekend
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
file3=pd.merge(file1,file2)

# %%
file3.head()
# Out:
#           timestamp  new_bike_shares  temperature  feels_like_temp  humidity  \
# 0  04/01/2015 00:00              182          3.0              2.0      93.0
# 1  04/01/2015 01:00              138          3.0              2.5      93.0
# 2  04/01/2015 02:00              134          2.5              2.5      96.5
# 3  04/01/2015 03:00               72          2.0              2.0     100.0
# 4  04/01/2015 04:00               47          2.0              0.0      93.0
#
#    wind_speed  is_weekend
# 0         6.0           1
# 1         5.0           1
# 2         0.0           1
# 3         0.0           1
# 4         6.5           1

# %%
file3.shape
# Out:
# (17414, 7)

# %%
file3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17414 entries, 0 to 17413
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   timestamp        17414 non-null  object
#  1   new_bike_shares  17414 non-null  int64
#  2   temperature      17414 non-null  float64
#  3   feels_like_temp  17414 non-null  float64
#  4   humidity         17414 non-null  float64
#  5   wind_speed       17414 non-null  float64
#  6   is_weekend       17414 non-null  int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 1.1+ MB

# %%
pd.isnull(file3)
# Out:
#        timestamp  new_bike_shares  temperature  feels_like_temp  humidity  \
# 0          False            False        False            False     False
# 1          False            False        False            False     False
# 2          False            False        False            False     False
# 3          False            False        False            False     False
# 4          False            False        False            False     False
# ...          ...              ...          ...              ...       ...
# 17409      False            False        False            False     False
# 17410      False            False        False            False     False
# 17411      False            False        False            False     False
# 17412      False            False        False            False     False
# 17413      False            False        False            False     False
#
#        wind_speed  is_weekend
# 0           False       False
# ...

# %%
file3.describe()
# Out:
#        new_bike_shares   temperature  feels_like_temp      humidity  \
# count     17414.000000  17414.000000     17414.000000  17414.000000
# mean       1143.101642     12.468091        11.520836     72.324954
# std        1085.108068      5.571818         6.615145     14.313186
# min           0.000000     -1.500000        -6.000000     20.500000
# 25%         257.000000      8.000000         6.000000     63.000000
# 50%         844.000000     12.500000        12.500000     74.500000
# 75%        1671.750000     16.000000        16.000000     83.000000
# max        7860.000000     34.000000        34.000000    100.000000
#
#          wind_speed    is_weekend
# count  17414.000000  17414.000000
# mean      15.913063      0.285403
# std        7.894570      0.451619
# min        0.000000      0.000000
# 25%       10.000000      0.000000
# 50%       15.000000      0.000000
# 75%       20.500000      1.000000
# max       56.500000      1.000000

# %%
file3.drop(file3[file3['new_bike_shares']<20].index,inplace=True)

# %%
file3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17373 entries, 0 to 17413
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   timestamp        17373 non-null  object
#  1   new_bike_shares  17373 non-null  int64
#  2   temperature      17373 non-null  float64
#  3   feels_like_temp  17373 non-null  float64
#  4   humidity         17373 non-null  float64
#  5   wind_speed       17373 non-null  float64
#  6   is_weekend       17373 non-null  int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 1.1+ MB

# %%
pd.isnull(file3)
# Out:
#        timestamp  new_bike_shares  temperature  feels_like_temp  humidity  \
# 0          False            False        False            False     False
# 1          False            False        False            False     False
# 2          False            False        False            False     False
# 3          False            False        False            False     False
# 4          False            False        False            False     False
# ...          ...              ...          ...              ...       ...
# 17409      False            False        False            False     False
# 17410      False            False        False            False     False
# 17411      False            False        False            False     False
# 17412      False            False        False            False     False
# 17413      False            False        False            False     False
#
#        wind_speed  is_weekend
# 0           False       False
# ...

# %%
file3.describe()
# Out:
#        new_bike_shares   temperature  feels_like_temp      humidity  \
# count     17373.000000  17373.000000     17373.000000  17373.000000
# mean       1145.763599     12.480391        11.536541     72.294840
# std        1085.001662      5.568546         6.610268     14.312539
# min          20.000000     -1.500000        -6.000000     20.500000
# 25%         260.000000      8.000000         6.000000     63.000000
# 50%         846.000000     12.500000        12.500000     74.500000
# 75%        1675.000000     16.000000        16.000000     83.000000
# max        7860.000000     34.000000        34.000000    100.000000
#
#          wind_speed    is_weekend
# count  17373.000000  17373.000000
# mean      15.912340      0.285961
# std        7.893567      0.451884
# min        0.000000      0.000000
# 25%       10.000000      0.000000
# 50%       15.000000      0.000000
# 75%       20.500000      1.000000
# max       56.500000      1.000000

# %%
sns.jointplot(x='new_bike_shares',y='timestamp',data=file3)

# %%
import datetime

# %%
file3["Date"] = pd.to_datetime(file3["timestamp"])
# check if the day is weekday or weekend
file3["IsWeekend"] = file3["Date"].dt.weekday >= 5

# %%
print(file3)
# Out:
#               timestamp  new_bike_shares  temperature  feels_like_temp  \
# 0      04/01/2015 00:00              182          3.0              2.0
# 1      04/01/2015 01:00              138          3.0              2.5
# 2      04/01/2015 02:00              134          2.5              2.5
# 3      04/01/2015 03:00               72          2.0              2.0
# 4      04/01/2015 04:00               47          2.0              0.0
# ...                 ...              ...          ...              ...
# 17409  03/01/2017 19:00             1042          5.0              1.0
# 17410  03/01/2017 20:00              541          5.0              1.0
# 17411  03/01/2017 21:00              337          5.5              1.5
# 17412  03/01/2017 22:00              224          5.5              1.5
# 17413  03/01/2017 23:00              139          5.0              1.0
#
#        humidity  wind_speed  is_weekend                Date  IsWeekend
# ...

# %%
file3.head(100)
# Out:
#             timestamp  new_bike_shares  temperature  feels_like_temp  \
# 0    04/01/2015 00:00              182          3.0              2.0
# 1    04/01/2015 01:00              138          3.0              2.5
# 2    04/01/2015 02:00              134          2.5              2.5
# 3    04/01/2015 03:00               72          2.0              2.0
# 4    04/01/2015 04:00               47          2.0              0.0
# ..                ...              ...          ...              ...
# 96   08/01/2015 01:00               56         11.5             11.5
# 97   08/01/2015 02:00               51         12.0             12.0
# 98   08/01/2015 03:00               33         12.0             12.0
# 99   08/01/2015 04:00               32         12.0             12.0
# 100  08/01/2015 05:00               87         12.0             12.0
#
#      humidity  wind_speed  is_weekend                Date  IsWeekend
# 0        93.0         6.0           1 2015-04-01 00:00:00      False
# ...

# %%
sns.relplot(x='new_bike_shares',y='Date',hue='IsWeekend',data=file3)

# %%
sns.jointplot(x='new_bike_shares',y='Date',hue='IsWeekend',data=file3)

# %%
# sns.catplot(x="Date", y="IsWeekend", data=file3);

# %%
file3[file3.columns[1:]].corr()['feels_like_temp'][:].sort_values(ascending=False).to_frame()
# Out:
#                  feels_like_temp
# feels_like_temp         1.000000
# temperature             0.988354
# new_bike_shares         0.367740
# wind_speed              0.088818
# IsWeekend              -0.007564
# is_weekend             -0.009871
# humidity               -0.402846

# %%
plt.figure(figsize=(15,10))
sns.set_theme(style="white")
corr = file3.corr()
heatmap = sns.heatmap(corr, annot=True, cmap="Blues", fmt='.2g')#if you change the fmt then you get different value

# %%
#feels_like_temp increases new_bike_shares decreases

# %%
plt.figure(figsize=(15,10))
sns.set_theme(style="white")
corr =file3.corr()
heatmap = sns.heatmap(corr, cmap="flare")

# %%
file3['feels_like_temp'].describe()
# Out:
# count    17373.000000
# mean        11.536541
# std          6.610268
# min         -6.000000
# 25%          6.000000
# 50%         12.500000
# 75%         16.000000
# max         34.000000
# Name: feels_like_temp, dtype: float64

# %%
from scipy import stats
from statsmodels.stats import weightstats as stests

# %%
feel_temp=file3['feels_like_temp']

# %%
print(feel_temp)
# Out:
# 0        2.0
# 1        2.5
# 2        2.5
# 3        2.0
# 4        0.0
#         ...
# 17409    1.0
# 17410    1.0
# 17411    1.5
# 17412    1.5
# 17413    1.0
# Name: feels_like_temp, Length: 17373, dtype: float64

# %%
feel_temp_mean=np.mean(feel_temp)

# %%
print(feel_temp_mean)
# Out:
# 11.536541376465204

# %%
ztest,pval=stests.ztest(file3['feels_like_temp'],value=11.5)

# %%
print(pval)
# Out:
# 0.46623191294290844

# %%
if pval<0.05:
    print("it will reject the null hypothesis")
else:
    print("it will Accept the Null hypothesis")
# Out:
# it will Accept the Null hypothesis
